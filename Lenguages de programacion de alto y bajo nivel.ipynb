# %% [markdown]
#                              📔¿Qué es un lenguaje de alto nivel?
# Un lenguaje de programación de alto nivel se caracteriza por su enfoque en la simplicidad y la accesibilidad para los programadores. A diferencia de los lenguajes de máquina o ensamblador, este tipo de lenguaje se escribe usando palabras, frases y estructuras que son más fáciles de entender para los humanos, permitiendo que los desarrolladores se concentren en la lógica de sus programas en lugar de preocuparse por detalles técnicos del hardware.
#
# Su principal ventaja reside en el nivel de abstracción que proporciona. Los lenguajes de alto nivel ocultan las complejidades del hardware, como la gestión de memoria o el direccionamiento de los procesadores, facilitando el desarrollo de software de una manera más eficiente y amigable.
#
#
#                      📑 Características principales de los lenguajes de alto nivel
# Existen ciertas características que distinguen a los lenguajes de alto nivel del resto. Estas cualidades los convierten en una herramienta esencial para los desarrolladores, ya que simplifican el proceso de programación. A continuación, exploramos algunas de estas características en profundidad:
#
# ✔️Sintaxis sencilla y cercana al lenguaje humano: Los lenguajes de alto nivel utilizan palabras y estructuras similares al idioma inglés, lo que facilita su comprensión.
#
# ✔️Abstracción del hardware: Ocultan detalles técnicos para que los programadores puedan enfocarse en la lógica del programa.
#
# ✔️Portabilidad: Estos lenguajes permiten que un mismo programa funcione en diferentes sistemas operativos y plataformas sin modificaciones significativas.
#
# ✔️Gestión automática de memoria: Los lenguajes de alto nivel, como Python, suelen encargarse de la asignación y liberación de la memoria, reduciendo errores comunes.

# %% [markdown]
#                         📑 ¿Cómo funcionan los lenguajes de alto nivel?
# El funcionamiento de los lenguajes de alto nivel se basa en la traducción del código que escriben los programadores (código fuente) a un formato que las máquinas puedan entender (código máquina). Este proceso se realiza a través de programas traductores como compiladores o intérpretes.
#
# Un compilador toma todo el código fuente y lo traduce en un programa ejecutable antes de su ejecución. Por otro lado, un intérprete traduce y ejecuta el código línea por línea, lo que puede ser más eficiente para ciertas aplicaciones pero menos rápido en términos globales.
#
# Gracias a este proceso, los desarrolladores pueden escribir código en un lenguaje comprensible sin necesidad de preocuparse por el lenguaje de máquina, logrando así un desarrollo más ágil y flexible.
#
# Ejemplos populares de lenguajes de alto nivel
# Existen numerosos lenguajes de programación de alto nivel, y cada uno tiene sus propias características y áreas de aplicación. A continuación, te presentamos algunos de los más utilizados:
#
# ✅Python: Este lenguaje destaca por su sintaxis clara y su versatilidad, siendo ideal para aplicaciones de inteligencia artificial, análisis de datos y desarrollo web.
#
# ✅Java: Con su principio de «escribe una vez, ejecuta en cualquier lugar», es ampliamente utilizado en aplicaciones empresariales y desarrollo de Android.
#
# ✅C++: Una extensión del lenguaje C que añade capacidades de programación orientada a objetos.
#
# ✅BASIC: Aunque no es tan popular en la actualidad, su versión moderna, Visual Basic, sigue siendo útil para desarrollar aplicaciones en Windows.
#
#           Importancia de los lenguajes de alto nivel en el desarrollo de software moderno
# La evolución tecnológica ha llevado a la creación de herramientas y lenguajes que mejoran la productividad de los desarrolladores. Los lenguajes de alto nivel son esenciales en este contexto, ya que permiten desarrollar software más complejo en menos tiempo y con menos errores.
#
# De esta forma, los lenguajes de alto nivel no solo han democratizado el acceso a la programación, sino que también han impulsado la innovación tecnológica, permitiendo la creación de aplicaciones más sofisticadas y accesibles.
#
# Los lenguajes de alto nivel han marcado un cambio drástico, acercando la programación a más personas, simplificando procesos complicados e impulsando un desarrollo tecnológico sin precedentes.

# %% [markdown]
#                             📔 ¿Qué es el lenguaje de bajo nivel?
# Como decimos, la ciencia informática se basa en diferentes lenguajes de programación para que todas las funciones se lleven a cabo de forma adecuada.
#
# Son muchos los tipos de lenguaje con los que podemos trabajar, pero nosotros vamos a centrarnos en el de bajo nivel. Aunque la palabra “bajo” pueda sonarte a algo de menor calidad, en esta ocasión bajo no va a tener nada que ver con un aspecto negativo. Cuando hablamos de lenguaje de este tipo nos vamos a referir a aquel cuyas pautas de actuación están muy ligadas a las instrucciones del hardware y además suele depender de los ordenadores que utilizan dicho lenguaje.
#
# Principalmente el aspecto que más va a incidir de la computadora es el físico. El lenguaje de bajo nivel apenas se separa del hardware al que acompaña, pero no por ello va a ser menos potente, simplemente lo utilizaremos para otro tipo de tareas.
#
# En cualquier caso hay que tener en cuenta que este lenguaje funciona en mayor medida gracias a un proceso de instrucciones muy elaborado, por lo que es un tipo de lenguaje que revisa hasta el más mínimo detalle.
#
#                              📑 Tipos de lenguaje de bajo nivel
# Al hablar de lenguaje de bajo nivel no nos referimos a uno en concreto, de hecho este término engloba a tres tipos diferentes de lenguaje de bajo nivel, aunque todos ellos comparten características similares.
#
# ✔️El primero que nos encontramos es el famoso Código Binario. Seguro que has oído hablar en más de una ocasión de él y es que es el lenguaje más básico que forma parte de todos los sistemas informáticos. Es muy habitual por ser bastante sencillo de utilizar. Tan solo se usan dos números para formar el código, el 1 que representa al “todo” y el 0 que por el contrario es el “nada”.
#
# ✔️En un segundo escalón se encuentra el lenguaje máquina. También bastante utilizado puesto que, como su propio nombre indica, este va a ser el código por el que se va a comunicar instrucciones a la máquina. Es indispensable el uso de este lenguaje, ya que con él se envían de forma literal todas las tareas que hay que llevar a cabo.
#
# ✔️Por último tenemos el lenguaje ensamblador, algo más complicado porque los códigos que utiliza no los descifra directamente el ordenador, por lo que habrá que pasarlo a lenguaje de máquina para que la computadora entienda la orden que estamos queriendo transmitirle. Es un tipo de lenguaje muy ligado al hardware y además necesita herramientas especiales para convertirlo a otro lenguaje.

# %% [markdown]
#                                   📑 Características
# El lenguaje de bajo nivel suele presentar bastantes ventajas, puesto que utiliza un código sencillo con instrucciones directas, de fácil conversión y es muy adaptable, además de que trabaja a gran velocidad.
#
# En contraposición a estas características positivas podemos encontrarnos algunas pequeñas desventajas, como es el caso de que este lenguaje está demasiado ligado al hardware, lo que hace que sea complicado estructurar algunos programas. De igual modo, también se necesita una especial atención en el momento de usarlo para no cometer errores que puedan aumentar de forma sensible el trabajo y la revisión que se haga del código.
#
# A día de hoy, con lo bueno y con lo malo, el lenguaje de bajo nivel se ha establecido como uno de los referentes para los profesionales de la industria tecnológica. Tiene una importancia extrema y es conveniente dominarlo en todas sus vertientes para poder desenvolvernos con eficacia bajo todo tipo de situaciones. Con él muchos grandes proyectos tecnológicos se llevan a cabo con muy buenos resultados y aporta importantes características que no tiene el lenguaje de alto nivel.
#
#                 📝¿Cuáles son las ventajas de un lenguaje de programación de bajo nivel?
# Las ventajas de un lenguaje de programación de bajo nivel son las siguientes:
#
# ✅Control directo sobre el hardware.
#
# ✅Eficiencia en la ejecución del código.
#
# ✅Menor abstracción, permitiendo optimizaciones específicas.
#
# ✅Consumo reducido de recursos.
#
# ✅Menor dependencia de bibliotecas externas.
#
# ✅Capacidad para escribir sistemas operativos y drivers.
#
# ✅Precisión en tareas de tiempo real.
#
# ✅Acceso directo a registros y memoria.
#
# ✅Flexibilidad para tareas específicas de la máquina.
#
# ✅Capacidad para crear código autocontenido.
#
#                 📝¿Cuáles son las desventajas de un lenguaje de programación de bajo nivel?
# Las desventajas de un lenguaje de programación de bajo nivel son las siguientes:
#
# ✅Requiere un conocimiento detallado del hardware.
#
# ✅Mayor complejidad en la escritura y lectura del código.
#
# ✅Menor portabilidad entre diferentes sistemas.
#
# ✅Desarrollo de software más lento.
#
# ✅Mayor probabilidad de errores y fallos.
#
# ✅Dificultad en la realización de tareas de alto nivel.
#
# ✅Necesidad de gestionar manualmente recursos como la memoria.
#
# ✅Falta de abstracción en estructuras y operaciones.
#
# ✅Menos herramientas y bibliotecas disponibles.
#
# ✅Requiere una curva de aprendizaje más pronunciada.
